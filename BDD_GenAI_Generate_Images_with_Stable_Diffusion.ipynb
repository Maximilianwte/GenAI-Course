# %% [markdown]
# <a href="https://colab.research.google.com/github/Maximilianwte/GenAI-Course/blob/main/BDD_GenAI_Generate_Images_with_Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq diffusers bitsandbytes accelerate

# %%
import torch
from diffusers import StableDiffusion3Pipeline
import matplotlib.pyplot as plt

hf_token=""

# %%
pipe = StableDiffusion3Pipeline.from_pretrained(
    "stabilityai/stable-diffusion-3-medium-diffusers",
    text_encoder_3=None,
    tokenizer_3=None,
    torch_dtype=torch.float16,
    token=hf_token
)
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
image = pipe(
    prompt="a cat holding a sign that says hello world",
    height=768,
    width=768
).images[0]
plt.imshow(image)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
